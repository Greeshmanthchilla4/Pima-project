# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshmanthchilla4/Greeshmanthchilla4/blob/master/Pima_indian_diabetes_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Introduction to Pima Indian diabetes project**
#
# Here we have a health information of people of Pima community. By applying logics to answer questions by using Numpy,Pandas,matplotlib and seaborn.

# %% [markdown]
# **Necessary Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Basic Exploration of Data**
#
# ```
# # This is formatted as code
# ```

# %%
df  = pd.read_csv('mandatory_diabetes (1).csv')          #reading the csv file and naming the variable as 'df' just to make my code look simple 
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
cols = list(df.columns)
print(cols,end = " ")
# Out:
# ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# %%
len(cols)
# Out:
# 9

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.T
# Out:
#                               0       1        2       3        4        5    \
# Pregnancies                 6.000   1.000    8.000   1.000    0.000    5.000
# Glucose                   148.000  85.000  183.000  89.000  137.000  116.000
# BloodPressure              72.000  66.000   64.000  66.000   40.000   74.000
# SkinThickness              35.000  29.000    0.000  23.000   35.000    0.000
# Insulin                     0.000   0.000    0.000  94.000  168.000    0.000
# BMI                        33.600  26.600   23.300  28.100   43.100   25.600
# DiabetesPedigreeFunction    0.627   0.351    0.672   0.167    2.288    0.201
# Age                        50.000  31.000   32.000  21.000   33.000   30.000
# Outcome                     1.000   0.000    1.000   0.000    1.000    0.000
#
#                              6        7        8        9    ...      758  \
# Pregnancies                3.000   10.000    2.000    8.000  ...    1.000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
df.describe(include = 'all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.histplot(x = 'Glucose' , data = df)         #This graph shows that it is skewed symmetrical

# %%
sns.boxplot(x = 'Glucose', data  = df)   #This graph shows clearly that Glucose variable has outliers

# %%
df.Glucose.median()                    #It is skewed and it has outliers so measures of central tendency is median
# Out:
# 117.0

# %%
sns.histplot(x = "Outcome", data = )
# Out:
# 0     99
# 1    100
# dtype: int64
